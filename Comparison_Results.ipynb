# %% [markdown]
# # Support ticket router: Mac and Fireworks
# Both experiments are complete; the cloud training and inference resources have been released.
#
# Saved results from actual scripts. These are evidence cells, not a claim that training ran inside this notebook.
#
# See results/REPORT.md and PROJECT_WALKTHROUGH.md for methodology, cost and limitations.

# %%
import json
from pathlib import Path
print(Path('results/local-baseline-test/metrics.json').read_text())
# Out:
# {
#   "backend": "mlx",
#   "model": "models/qwen3-4b-4bit",
#   "adapter": null,
#   "split": "test",
#   "output": "/Users/nishokmini/project/5A-Fine-Tune-a-Support-Ticket-Router/results/local-baseline-test",
#   "limit": null,
#   "resume": false,
#   "n": 117,
#   "accuracy": 0.4444444444444444,
#   "macro_f1": 0.40058652823629787,
#   "invalid_outputs": 0,
#   "latency_median_seconds": 0.44589700002688915,
#   "latency_p95_seconds": 0.5202072418178432,
#   "classification_report": {
#     "Support general": {
#       "precision": 0.0,
#       "recall": 0.0,
#       "f1-score": 0.0,
#       "support": 30.0
#     },
#     "Fileservice": {
#       "precision": 0.8148148148148148,
#       "recall": 0.7857142857142857,
#       "f1-score": 0.8,
#       "support": 28.0
#     },
#     "O365": {
#       "precision": 0.5,
#       "recall": 0.7222222222222222,
#       "f1-score": 0.5909090909090909,
#       "support": 18.0
#     },
#     "EOL": {
#       "precision": 1.0,
# ...

# %%
import json
from pathlib import Path
print(Path('results/local-tuned-test/metrics.json').read_text())
# Out:
# {
#   "backend": "mlx",
#   "model": "models/qwen3-4b-4bit",
#   "adapter": "adapters/local-full",
#   "split": "test",
#   "output": "/Users/nishokmini/project/5A-Fine-Tune-a-Support-Ticket-Router/results/local-tuned-test",
#   "limit": null,
#   "resume": false,
#   "n": 117,
#   "accuracy": 0.8290598290598291,
#   "macro_f1": 0.7940122909067009,
#   "invalid_outputs": 0,
#   "latency_median_seconds": 0.5410269169951789,
#   "latency_p95_seconds": 0.622699832811486,
#   "classification_report": {
#     "Support general": {
#       "precision": 0.7878787878787878,
#       "recall": 0.8666666666666667,
#       "f1-score": 0.8253968253968254,
#       "support": 30.0
#     },
#     "Fileservice": {
#       "precision": 0.9615384615384616,
#       "recall": 0.8928571428571429,
#       "f1-score": 0.9259259259259259,
#       "support": 28.0
#     },
#     "O365": {
#       "precision": 0.8333333333333334,
#       "recall": 0.8333333333333334,
#       "f1-score": 0.8333333333333334,
# ...

# %%
import json
from pathlib import Path
print(Path('results/local-merged-8bit-test/metrics.json').read_text())
# Out:
# {
#   "backend": "mlx",
#   "model": "models/local-router-merged-8bit",
#   "adapter": null,
#   "split": "test",
#   "output": "/Users/nishokmini/project/5A-Fine-Tune-a-Support-Ticket-Router/results/local-merged-8bit-test",
#   "limit": null,
#   "resume": false,
#   "n": 117,
#   "accuracy": 0.8290598290598291,
#   "macro_f1": 0.7940122909067009,
#   "invalid_outputs": 0,
#   "latency_median_seconds": 0.5106232909602113,
#   "latency_p95_seconds": 0.6039382333983667,
#   "classification_report": {
#     "Support general": {
#       "precision": 0.7878787878787878,
#       "recall": 0.8666666666666667,
#       "f1-score": 0.8253968253968254,
#       "support": 30.0
#     },
#     "Fileservice": {
#       "precision": 0.9615384615384616,
#       "recall": 0.8928571428571429,
#       "f1-score": 0.9259259259259259,
#       "support": 28.0
#     },
#     "O365": {
#       "precision": 0.8333333333333334,
#       "recall": 0.8333333333333334,
#       "f1-score": 0.8333333333333334,
# ...

# %%
import json
from pathlib import Path
print(Path('results/local-merged-test/metrics.json').read_text())
# Out:
# {
#   "backend": "mlx",
#   "model": "models/local-router-merged",
#   "adapter": null,
#   "split": "test",
#   "output": "/Users/nishokmini/project/5A-Fine-Tune-a-Support-Ticket-Router/results/local-merged-test",
#   "limit": null,
#   "resume": false,
#   "n": 117,
#   "accuracy": 0.6153846153846154,
#   "macro_f1": 0.6198289931083989,
#   "invalid_outputs": 5,
#   "latency_median_seconds": 0.4565457919961773,
#   "latency_p95_seconds": 0.5630547247710636,
#   "classification_report": {
#     "Support general": {
#       "precision": 0.625,
#       "recall": 0.16666666666666666,
#       "f1-score": 0.2631578947368421,
#       "support": 30.0
#     },
#     "Fileservice": {
#       "precision": 0.9583333333333334,
#       "recall": 0.8214285714285714,
#       "f1-score": 0.8846153846153846,
#       "support": 28.0
#     },
#     "O365": {
#       "precision": 0.5517241379310345,
#       "recall": 0.8888888888888888,
#       "f1-score": 0.6808510638297872,
#       "support": 18.0
# ...

# %%
import json
from pathlib import Path
print(Path('results/fireworks-baseline-test/metrics.json').read_text())
# Out:
# {
#   "backend": "fireworks",
#   "model": "accounts/fireworks/models/llama-v3p2-3b-instruct#accounts/nishokvg-myac5qmcmir/deployments/support-router-eval-01",
#   "split": "test",
#   "format": "raw Llama3 training renderer; no date insertion",
#   "prompt_sha256": "49bed163e312fdd8ab146eb6b09e9641047092679b301fbab2318abed4c94edd",
#   "dataset_sha256": "d20d2a6baee1dd2449bc1698365e6297ce6883831fb89c46d2b45b7b8ae80871",
#   "generation": {
#     "temperature": 0,
#     "max_tokens": 16
#   },
#   "sequential_requests": true,
#   "warmup_excluded": true,
#   "n": 117,
#   "accuracy": 0.41025641025641024,
#   "macro_f1": 0.3154058454168312,
#   "invalid_outputs": 2,
#   "latency_median_seconds": 0.22215620800852776,
#   "latency_p95_seconds": 0.28196082457434335,
#   "classification_report": {
#     "Support general": {
#       "precision": 0.3333333333333333,
#       "recall": 0.3,
#       "f1-score": 0.3157894736842105,
#       "support": 30.0
#     },
#     "Fileservice": {
# ...

# %%
import json
from pathlib import Path
print(Path('results/fireworks-tuned-test/metrics.json').read_text())
# Out:
# {
#   "backend": "fireworks",
#   "model": "accounts/nishokvg-myac5qmcmir/models/support-router-llama3b-dedicated-01#accounts/nishokvg-myac5qmcmir/deployments/support-router-eval-01",
#   "split": "test",
#   "format": "raw Llama3 training renderer; no date insertion",
#   "prompt_sha256": "49bed163e312fdd8ab146eb6b09e9641047092679b301fbab2318abed4c94edd",
#   "dataset_sha256": "d20d2a6baee1dd2449bc1698365e6297ce6883831fb89c46d2b45b7b8ae80871",
#   "generation": {
#     "temperature": 0,
#     "max_tokens": 16
#   },
#   "sequential_requests": true,
#   "warmup_excluded": true,
#   "n": 117,
#   "accuracy": 0.8376068376068376,
#   "macro_f1": 0.8102659628005037,
#   "invalid_outputs": 0,
#   "latency_median_seconds": 0.21804770804010332,
#   "latency_p95_seconds": 0.23884306701365857,
#   "classification_report": {
#     "Support general": {
#       "precision": 0.7297297297297297,
#       "recall": 0.9,
#       "f1-score": 0.8059701492537313,
#       "support": 30.0
#     },
# ...

# %%
from IPython.display import Image, display
display(Image('results/comparison.png'))
# Out:
# <Figure: saved experiment results>

# %%
from IPython.display import Image, display
display(Image('results/training-losses.png'))
# Out:
# <Figure: saved experiment results>

# %%
from IPython.display import Image, display
display(Image('results/fireworks-tuned-confusion.png'))
# Out:
# <Figure: saved experiment results>
